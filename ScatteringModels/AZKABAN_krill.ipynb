# %% [markdown]
# This notebook is used to model the frequency response we *should* expect to get from the species that were inside AZKABAN

# %%
import os
import numpy as np
import pandas as pd
from scipy import signal
from scipy import optimize
from scipy import linalg
from scipy.interpolate import UnivariateSpline
import matplotlib
import matplotlib.pyplot as plt
import array as arr
import seaborn as sns
import random
import pylab
import glob
from scipy import stats
from sklearn import linear_model
from sklearn.pipeline import make_pipeline
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import datetime

import inverse_method_funs as inv

# %%
sns.set_theme(style="darkgrid")
sns.color_palette("viridis", as_cmap=True)
title_font = {
    'fontname': 'DejaVu Sans', 'size': '15', 'color': 'black',
    'weight': 'medium'
}
axis_font = {'fontname': 'DejaVu Sans', 'size': '15', 'color': 'black'}

# %% [markdown]
# # Read results from scattering models
# Scattering models for the copepods in the nets were run in ZooScatR, a package that runs PC-DWBA.
# Length distributions from the sample were used and literature values for orientation, g, h and width were used.
# There were also fish eggs, fish larvae and decapod larvae dominantly found in the net. These will be modeled if necessary later.

# %%
# Sigmabs from ZooScatR model runs + viscous elactic model for mean of fish larvae model by ve=True)
fname_sim = '../ZooScatStuff/my_data.feather'
specs, freqs_sim, sig_bs_mean, ci_boot = inv.read_scatteringmodelsimulations(fname_sim, nsim=1000, ve=False)

# %%
krill_ind = np.where(specs == 'Krill')
plt.plot(freqs_sim, sig_bs_mean[:,krill_ind[0]]);

# %% [markdown]
# # Sample
# Based on the sample counts from the experiment, there were 4600 copepods/m3

# %%
density = 10000
Sv_predicted = 10*np.log10(sig_bs_mean[:,krill_ind[0]]*density/10)

# %%
plt.plot(freqs_sim, Sv_predicted)
plt.xlim([180, 383])
plt.ylabel('Sv dB re $1m^{-1}$')
plt.xlabel('Frequency (kHz)')
# Out:
# Text(0.5, 0, 'Frequency (kHz)')

# %% [markdown]
# # Add actual measurements

# %% [markdown]
# Load wideband frequency response exported from Echoview.
# The measurements from the 200 kHz and 333 kHz inside the net at ~5m depth

# %%
fname_200 = 'D:/AZKABAN-Data/ExperimentDays/WBATdata/WBfreqresp_200_270421.csv'
freqs_200, sv_out200, times_200 = inv.read_widebandfrequencyresponse(fname_200)
Sv_200 = 10*np.log10(sv_out200/10)
fname_333 = 'F:\AZKABAN-Data\ExperimentDays\WBATdata\WBfreqresp_333_270421.csv'
freqs_333, sv_out333, times_333 = inv.read_widebandfrequencyresponse(fname_333)
Sv_333= 10*np.log10(sv_out333/10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_99588/4006117792.py in <module>
#       1 fname_200 = 'D:/AZKABAN-Data/ExperimentDays/WBATdata/WBfreqresp_200_270421.csv'
# ----> 2 freqs_200, sv_out200, times_200 = inv.read_widebandfrequencyresponse(fname_200)
#       3 Sv_200 = 10*np.log10(sv_out200/10)
#       4 fname_333 = 'F:\AZKABAN-Data\ExperimentDays\WBATdata\WBfreqresp_333_270421.csv'
#       5 freqs_333, sv_out333, times_333 = inv.read_widebandfrequencyresponse(fname_333)
#
# ~\phd\ScatteringModels\inverse_method_funs.py in read_widebandfrequencyresponse(fname, header, extracols, source)
#      26     """
#      27     if source=='Echoview':
# ---> 28         wideband_extract = pd.read_csv(fname, header=0, index_col = 0)
#      29         data = wideband_extract.T
#      30
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     704                 encoding=ioargs.encoding,
#     705                 errors=errors,
# --> 706                 newline="",
#     707             )
#     708         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/AZKABAN-Data/ExperimentDays/WBATdata/WBfreqresp_200_270421.csv'

# %%
# Plot all
plt.figure(figsize=(8,5))
plt.plot(freqs_sim, Sv_predicted, 'k', label='Predicted')
plt.plot(freqs_200, Sv_200[:,0], 'r', label='Measured')
plt.plot(freqs_333, Sv_333[:,0], 'r', label='Measured')
plt.ylabel('Sv dB re $1m^{-1}$')
plt.xlabel('Frequency (kHz)')
plt.xlim([180, 400])
plt.legend(fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_99588/1924118924.py in <module>
#       2 plt.figure(figsize=(8,5))
#       3 plt.plot(freqs_sim, Sv_predicted, 'k', label='Predicted')
# ----> 4 plt.plot(freqs_200, Sv_200[:,0], 'r', label='Measured')
#       5 plt.plot(freqs_333, Sv_333[:,0], 'r', label='Measured')
#       6 plt.ylabel('Sv dB re $1m^{-1}$')
#
# NameError: name 'freqs_200' is not defined

# %% [markdown]
# # Compare with empty net
# Empty(mt) net but comparable will be data from AZKABAN Day 1

# %%
fname_200_mt = 'F:/AZKABAN-Data/ExperimentDays/WBATdata/WBfreqresp_200_190421.csv'
freqs_200_mt, sv_out200_mt, times_200_mt = inv.read_widebandfrequencyresponse(fname_200_mt)
Sv_200_mt = 10*np.log10(sv_out200_mt/10)
fname_333_mt = 'F:\AZKABAN-Data\ExperimentDays\WBATdata\WBfreqresp_333_190421.csv'
freqs_333_mt, sv_out333_mt, times_333_mt = inv.read_widebandfrequencyresponse(fname_333_mt)
Sv_333_mt= 10*np.log10(sv_out333_mt/10)

# %%
# Plot all
plt.figure(figsize=(10,5))
plt.title('AZKABAN frequency response analysis', title_font)
plt.plot(freqs_sim, Sv_predicted, 'k', label=' Predicted Mean - %4.0f ind/m3' %(density))
plt.plot(freqs_200, Sv_200[:,-1], 'r', label='Measured Populated - April 27 2021')
plt.plot(freqs_333, Sv_333[:,-1], 'r', label='Measured Populated - April 27 2021')
plt.plot(freqs_200_mt, Sv_200_mt[:,-1], 'm', label='Measured Empty - April 19 2021')
plt.plot(freqs_333_mt, Sv_333_mt[:,-1], 'm', label='Measured Empty - April 19 2021')
plt.ylabel('Sv (dB re $1m^{-1}$)', axis_font)
plt.xlabel('Frequency (kHz)', axis_font)
plt.xlim([180, 400])
plt.legend(fontsize=14)
