# %% [markdown]
# In this notebook I will plot CTD files from ARCTOS cruise

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline
import array as arr
import datetime

# %%
sns.set_theme(style="darkgrid")
sns.color_palette("viridis", as_cmap=True)
title_font = {
    'fontname': 'DejaVu Sans', 'size': '15', 'color': 'black',
    'weight': 'medium'
}
axis_font = {'fontname': 'DejaVu Sans', 'size': '15', 'color': 'black'}

# %% [markdown]
# Specifically I will focus on the two CTD casts of Station 2. At Station 2 we got large amounts of polar cod in the pelagic and bottom trawl, with minimal other fish. These trawls were 4.5 h apart but only a few km apart.

# %% [markdown]
# ### Distance between pelagic and bottom trawl

# %%
lat_pel = 77.275
lat_bunn = 77.243

60*1.853*(lat_pel-lat_bunn)
# Out:
# 3.557760000001188

# %% [markdown]
# 40 m depth difference, 3.5 km and 4.5 h between polar cod dominated trawls

# %% [markdown]
# ## read ctd files

# %%
ctd_1 = pd.read_table('C:/Users/mbd/OneDrive - Akvaplan-niva AS/PhD-APN/ChaptersandExperiments/ARCTOScruise/CTDdata/stnr0489.txt', header=0)

# %%
ctd_2 = pd.read_table('C:/Users/mbd/OneDrive - Akvaplan-niva AS/PhD-APN/ChaptersandExperiments/ARCTOScruise/CTDdata/stnr0489.txt', header=0)

# %%
plt.plot(ctd_1['t090C: Temperature [ITS-90, deg C]'], ctd_1['depSM: Depth [salt water, m]'])
#plt.plot(,ctd_2['depSM: Depth [salt water, m]'])
plt.ylim([180,0])
plt.title('Station 2', title_font)
plt.ylabel('Depth (m)', axis_font)
plt.xlabel('Temperature (deg C)', axis_font)
# Out:
# Text(0.5, 0, 'Temperature (deg C)')
