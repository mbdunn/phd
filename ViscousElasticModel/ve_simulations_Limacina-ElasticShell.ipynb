# %%
import numpy as np
import numpy.matlib as ml
import scipy.stats as stats
import matplotlib.pyplot as plt
import csv
import pandas as pd
from sklearn.utils import resample
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")
sns.color_palette("viridis", as_cmap=True)
title_font = {
    'fontname': 'DejaVu Sans', 'size': '15', 'color': 'black',
    'weight': 'medium'
}
axis_font = {'fontname': 'DejaVu Sans', 'size': '15', 'color': 'black'}

# %%
import os
import FUNC_Stable3_GasSphere_ElasticShellViscFlesh as vefunc

# %% [markdown]
# # Fixed Parameters
# Most parameters are fixed for Limacina

# %%
M_order=3

ro1=1027    # Surronding Water density  "kg/m³"
ro2=1040  # Surronding viscouis layer (fish flesh) density  "kg/m³" 
ro3=2931  # Elastic sphere Density "kg/m³"  # Hard aragonite shell
ro4= 1050 # Inner Gas Sphere Density "kg/m³" internal tissue (MacLennan and Simmonds 2005) g agrees with Lavery 2007. g=1.022

c1=1462    # Surronding Water speed of sound "m/s" @ 4,3deg 31,2 PSU
c2=1523    # Surronding viscouis layer (fish flesh) speed of sound "m/s"
#c3=1480    # Elastic sphere speed of sound "m/s"
c4=c2    # gas speed of sound "m/s" As fish flesh, internal tissue (MacLennan and Simmonds 2005) agrees with Lavery 2007 

Eta2=2*0.428572
Mu2=Eta2
Kisi2=Mu2+4*Eta2/3
    
Mu3=35800*1.0E6  # "N/m²" shear rigidity of elastic shell aragonite sheer modulus
Landa3=2.4*1E9  # "N/m²" Compressional rigidity of elastic shell

c3=(ro3/(Landa3+2*Mu3))**-0.5    # Elastic sphere speed of sound "m/s"

# %%
# calculate g and h for inside radius
g4 = ro4/ro1
h4 = c4/c1
print('sound speed contrast h='+str(h4)+' and density contrast g='+str(g4))
# Out:
# sound speed contrast h=1.0417236662106704 and density contrast g=1.0223953261927945

# %%
# set fixed values
params_lima ={'ro1':ro1,
            'ro2':ro2,
            'ro3':ro3,
            'ro4':ro4,
            'c1':c1,
            'c2':c2,
            'c3':c3,
            'c4':c4,
            'Eta2':Eta2,
            'Mu3':Mu3,
            'Landa3':Landa3,
            'Kisi2':Kisi2}

# %% [markdown]
# ## Variable Parameters
# For these model simulations the only variable with distribution is the **SHAPE.**
#
# The main variable parameter is R3- the radius of the swimbladder including the wall. In the case of Limacina it is the whole measured length (or calculated width).
#
# The other two variable parameters are R4- radius of the swimbladder (R3-thickness of swimbladder wall) and R2-radius of fish fesh, since there is not flesh around the shell in a Limacina, we use R4=R3.

# %%
# Radius R3 distribution
# Values from lengthDist.Rmd. scale is 1/rate. shape is alpha. 
# radius distribution was calculated using all measured lengths (divided by 2!) and their associated widths(Divided by 2!) (L/a=1.5 Stanton 2000)
x=np.arange(0,5,0.01)
R3_dist = stats.gamma.pdf(x,a=5.4,scale=1/9.17)

plt.plot(x,R3_dist)
plt.plot(np.random.gamma(5.4,1/9.17),0, '.')
plt.title('Distribution for Limacina (R3) radius w/ swimbladder wall', title_font)
plt.xlabel('Radius (mm)', axis_font)
plt.ylabel('Probability', axis_font);

# %% [markdown]
# ## Set up simulation

# %%
# Frequency range
min_freq=100*1000
max_freq=600*1000
frequencySpacing=500
Freq_vec=np.arange(min_freq,max_freq,frequencySpacing)

# %% [markdown]
# ## Run ensembles

# %%
nsim = 1000
nfreqs = len(Freq_vec)

# Allocate space for speed
R3_ensemble = np.zeros((nsim,1))
R4_ensemble = np.zeros((nsim,1))
TS_simulations = np.zeros((nsim*nfreqs))
freqs=np.zeros((nsim*nfreqs))

for ind_sim in np.arange(nsim):
    
    # Set new radius parameters
    R3 = np.random.gamma(5.4,1/4.6)*1e-3
    params_lima['R3'] = R3
    params_lima['R2'] = R3
    params_lima['R4'] = R3  - (R3*0.023) 
    
    # Run the v-e model
    print('Running simulations for SB radius %.2f mm, simulation %.0f' %(R3*1000,ind_sim))
    TS_vec_lima = vefunc.run_ve(Freq_vec, M_order, params_lima)
    
    # Save each iterated radius values
    R3_ensemble[ind_sim] = R3
    R4_ensemble[ind_sim] = params_lima['R4']

    # Save all results.
    TS_simulations[ind_sim*nfreqs:ind_sim*nfreqs+nfreqs] = TS_vec_lima
    freqs[ind_sim*nfreqs:ind_sim*nfreqs+nfreqs] = Freq_vec
# Out:
# Running simulations for SB radius 0.31 mm, simulation 0
# Running simulations for SB radius 0.86 mm, simulation 1
# Running simulations for SB radius 0.98 mm, simulation 2
# Running simulations for SB radius 1.14 mm, simulation 3
# Running simulations for SB radius 0.51 mm, simulation 4
# Running simulations for SB radius 2.15 mm, simulation 5
# Running simulations for SB radius 1.17 mm, simulation 6
# Running simulations for SB radius 0.92 mm, simulation 7
# Running simulations for SB radius 1.20 mm, simulation 8
# Running simulations for SB radius 0.68 mm, simulation 9
# Running simulations for SB radius 0.81 mm, simulation 10
# Running simulations for SB radius 1.47 mm, simulation 11
# Running simulations for SB radius 1.50 mm, simulation 12
# Running simulations for SB radius 2.87 mm, simulation 13
# Running simulations for SB radius 0.68 mm, simulation 14
# Running simulations for SB radius 1.86 mm, simulation 15
# Running simulations for SB radius 0.43 mm, simulation 16
# Running simulations for SB radius 1.07 mm, simulation 17
# Running simulations for SB radius 2.40 mm, simulation 18
# Running simulations for SB radius 0.72 mm, simulation 19
# Running simulations for SB radius 0.48 mm, simulation 20
# Running simulations for SB radius 2.10 mm, simulation 21
# Running simulations for SB radius 1.14 mm, simulation 22
# Running simulations for SB radius 2.17 mm, simulation 23
# Running simulations for SB radius 1.21 mm, simulation 24
# Running simulations for SB radius 0.65 mm, simulation 25
# Running simulations for SB radius 1.25 mm, simulation 26
# Running simulations for SB radius 0.72 mm, simulation 27
# Running simulations for SB radius 0.25 mm, simulation 28
# Running simulations for SB radius 1.56 mm, simulation 29
# Running simulations for SB radius 0.97 mm, simulation 30
# Running simulations for SB radius 1.74 mm, simulation 31
# Running simulations for SB radius 1.42 mm, simulation 32
# Running simulations for SB radius 0.84 mm, simulation 33
# Running simulations for SB radius 1.87 mm, simulation 34
# Running simulations for SB radius 1.20 mm, simulation 35
# Running simulations for SB radius 0.80 mm, simulation 36
# Running simulations for SB radius 0.61 mm, simulation 37
# Running simulations for SB radius 0.89 mm, simulation 38
# Running simulations for SB radius 1.01 mm, simulation 39
# Running simulations for SB radius 1.20 mm, simulation 40
# Running simulations for SB radius 2.80 mm, simulation 41
# Running simulations for SB radius 1.81 mm, simulation 42
# Running simulations for SB radius 0.37 mm, simulation 43
# Running simulations for SB radius 1.58 mm, simulation 44
# Running simulations for SB radius 1.25 mm, simulation 45
# Running simulations for SB radius 0.85 mm, simulation 46
# Running simulations for SB radius 1.44 mm, simulation 47
# Running simulations for SB radius 1.09 mm, simulation 48
# Running simulations for SB radius 1.17 mm, simulation 49
# Running simulations for SB radius 0.58 mm, simulation 50
# Running simulations for SB radius 1.13 mm, simulation 51
# Running simulations for SB radius 1.25 mm, simulation 52
# Running simulations for SB radius 1.46 mm, simulation 53
# Running simulations for SB radius 1.80 mm, simulation 54
# Running simulations for SB radius 1.49 mm, simulation 55
# Running simulations for SB radius 1.12 mm, simulation 56
# Running simulations for SB radius 1.77 mm, simulation 57
# Running simulations for SB radius 1.73 mm, simulation 58
# Running simulations for SB radius 2.11 mm, simulation 59
# Running simulations for SB radius 1.18 mm, simulation 60
# Running simulations for SB radius 1.21 mm, simulation 61
# Running simulations for SB radius 0.58 mm, simulation 62
# Running simulations for SB radius 1.20 mm, simulation 63
# Running simulations for SB radius 1.32 mm, simulation 64
# Running simulations for SB radius 1.32 mm, simulation 65
# Running simulations for SB radius 1.14 mm, simulation 66
# Running simulations for SB radius 1.48 mm, simulation 67
# Running simulations for SB radius 1.35 mm, simulation 68
# Running simulations for SB radius 2.33 mm, simulation 69
# Running simulations for SB radius 1.15 mm, simulation 70
# Running simulations for SB radius 1.39 mm, simulation 71
# Running simulations for SB radius 1.10 mm, simulation 72
# Running simulations for SB radius 0.81 mm, simulation 73
# Running simulations for SB radius 1.15 mm, simulation 74
# Running simulations for SB radius 0.85 mm, simulation 75
# Running simulations for SB radius 0.50 mm, simulation 76
# Running simulations for SB radius 1.15 mm, simulation 77
# Running simulations for SB radius 2.23 mm, simulation 78
# Running simulations for SB radius 0.58 mm, simulation 79
# Running simulations for SB radius 1.46 mm, simulation 80
# Running simulations for SB radius 0.94 mm, simulation 81
# Running simulations for SB radius 0.71 mm, simulation 82
# Running simulations for SB radius 1.41 mm, simulation 83
# Running simulations for SB radius 2.19 mm, simulation 84
# Running simulations for SB radius 1.12 mm, simulation 85
# Running simulations for SB radius 2.34 mm, simulation 86
# Running simulations for SB radius 1.28 mm, simulation 87
# Running simulations for SB radius 1.96 mm, simulation 88
# Running simulations for SB radius 1.29 mm, simulation 89
# Running simulations for SB radius 1.21 mm, simulation 90
# Running simulations for SB radius 1.51 mm, simulation 91
# Running simulations for SB radius 1.36 mm, simulation 92
# Running simulations for SB radius 1.49 mm, simulation 93
# Running simulations for SB radius 1.05 mm, simulation 94
# Running simulations for SB radius 0.99 mm, simulation 95
# Running simulations for SB radius 1.65 mm, simulation 96
# Running simulations for SB radius 0.59 mm, simulation 97
# Running simulations for SB radius 0.99 mm, simulation 98
# Running simulations for SB radius 1.63 mm, simulation 99
# Running simulations for SB radius 1.46 mm, simulation 100
# Running simulations for SB radius 1.27 mm, simulation 101
# Running simulations for SB radius 0.30 mm, simulation 102
# Running simulations for SB radius 1.94 mm, simulation 103
# Running simulations for SB radius 1.01 mm, simulation 104
# Running simulations for SB radius 0.56 mm, simulation 105
# Running simulations for SB radius 0.73 mm, simulation 106
# Running simulations for SB radius 0.75 mm, simulation 107
# Running simulations for SB radius 1.00 mm, simulation 108
# Running simulations for SB radius 1.04 mm, simulation 109
# Running simulations for SB radius 0.91 mm, simulation 110
# Running simulations for SB radius 1.36 mm, simulation 111
# Running simulations for SB radius 1.78 mm, simulation 112
# Running simulations for SB radius 1.14 mm, simulation 113
# Running simulations for SB radius 1.69 mm, simulation 114
# Running simulations for SB radius 1.20 mm, simulation 115
# Running simulations for SB radius 0.86 mm, simulation 116
# Running simulations for SB radius 1.20 mm, simulation 117
# Running simulations for SB radius 0.96 mm, simulation 118
# Running simulations for SB radius 0.88 mm, simulation 119
# Running simulations for SB radius 0.43 mm, simulation 120
# Running simulations for SB radius 0.69 mm, simulation 121
# Running simulations for SB radius 1.38 mm, simulation 122
# Running simulations for SB radius 1.39 mm, simulation 123
# Running simulations for SB radius 0.76 mm, simulation 124
# Running simulations for SB radius 1.04 mm, simulation 125
# Running simulations for SB radius 0.82 mm, simulation 126
# Running simulations for SB radius 0.88 mm, simulation 127
# Running simulations for SB radius 0.57 mm, simulation 128
# Running simulations for SB radius 1.23 mm, simulation 129
# Running simulations for SB radius 1.47 mm, simulation 130
# Running simulations for SB radius 1.16 mm, simulation 131
# Running simulations for SB radius 0.83 mm, simulation 132
# Running simulations for SB radius 0.81 mm, simulation 133
# Running simulations for SB radius 0.36 mm, simulation 134
# Running simulations for SB radius 1.58 mm, simulation 135
# Running simulations for SB radius 0.79 mm, simulation 136
# Running simulations for SB radius 1.28 mm, simulation 137
# Running simulations for SB radius 0.80 mm, simulation 138
# Running simulations for SB radius 1.73 mm, simulation 139
# Running simulations for SB radius 1.69 mm, simulation 140
# Running simulations for SB radius 0.92 mm, simulation 141
# Running simulations for SB radius 1.25 mm, simulation 142
# Running simulations for SB radius 2.11 mm, simulation 143
# Running simulations for SB radius 1.03 mm, simulation 144
# Running simulations for SB radius 1.42 mm, simulation 145
# Running simulations for SB radius 2.72 mm, simulation 146
# Running simulations for SB radius 1.38 mm, simulation 147
# Running simulations for SB radius 1.18 mm, simulation 148
# Running simulations for SB radius 1.69 mm, simulation 149
# Running simulations for SB radius 1.11 mm, simulation 150
# Running simulations for SB radius 1.07 mm, simulation 151
# Running simulations for SB radius 0.92 mm, simulation 152
# Running simulations for SB radius 0.82 mm, simulation 153
# Running simulations for SB radius 2.32 mm, simulation 154
# Running simulations for SB radius 1.75 mm, simulation 155
# Running simulations for SB radius 1.99 mm, simulation 156
# Running simulations for SB radius 0.83 mm, simulation 157
# Running simulations for SB radius 1.01 mm, simulation 158
# Running simulations for SB radius 1.29 mm, simulation 159
# Running simulations for SB radius 0.96 mm, simulation 160
# Running simulations for SB radius 1.15 mm, simulation 161
# Running simulations for SB radius 0.65 mm, simulation 162
# Running simulations for SB radius 0.68 mm, simulation 163
# Running simulations for SB radius 1.56 mm, simulation 164
# Running simulations for SB radius 1.74 mm, simulation 165
# Running simulations for SB radius 1.16 mm, simulation 166
# Running simulations for SB radius 0.91 mm, simulation 167
# Running simulations for SB radius 1.95 mm, simulation 168
# Running simulations for SB radius 0.85 mm, simulation 169
# Running simulations for SB radius 0.84 mm, simulation 170
# Running simulations for SB radius 0.79 mm, simulation 171
# Running simulations for SB radius 1.24 mm, simulation 172
# Running simulations for SB radius 1.66 mm, simulation 173
# Running simulations for SB radius 1.09 mm, simulation 174
# Running simulations for SB radius 1.07 mm, simulation 175
# Running simulations for SB radius 2.11 mm, simulation 176
# Running simulations for SB radius 1.67 mm, simulation 177
# Running simulations for SB radius 1.10 mm, simulation 178
# Running simulations for SB radius 2.07 mm, simulation 179
# Running simulations for SB radius 0.72 mm, simulation 180
# Running simulations for SB radius 1.80 mm, simulation 181
# Running simulations for SB radius 1.17 mm, simulation 182
# Running simulations for SB radius 0.76 mm, simulation 183
# Running simulations for SB radius 1.16 mm, simulation 184
# Running simulations for SB radius 2.04 mm, simulation 185
# Running simulations for SB radius 0.77 mm, simulation 186
# Running simulations for SB radius 0.68 mm, simulation 187
# Running simulations for SB radius 0.94 mm, simulation 188
# Running simulations for SB radius 1.09 mm, simulation 189
# Running simulations for SB radius 1.25 mm, simulation 190
# Running simulations for SB radius 1.86 mm, simulation 191
# Running simulations for SB radius 1.22 mm, simulation 192
# Running simulations for SB radius 1.07 mm, simulation 193
# Running simulations for SB radius 0.89 mm, simulation 194
# Running simulations for SB radius 2.06 mm, simulation 195
# Running simulations for SB radius 2.81 mm, simulation 196
# Running simulations for SB radius 1.49 mm, simulation 197
# Running simulations for SB radius 0.72 mm, simulation 198
# Running simulations for SB radius 1.48 mm, simulation 199
# Running simulations for SB radius 1.51 mm, simulation 200
# Running simulations for SB radius 1.31 mm, simulation 201
# Running simulations for SB radius 1.40 mm, simulation 202
# Running simulations for SB radius 1.17 mm, simulation 203
# Running simulations for SB radius 1.49 mm, simulation 204
# Running simulations for SB radius 1.99 mm, simulation 205
# Running simulations for SB radius 3.23 mm, simulation 206
# Running simulations for SB radius 2.50 mm, simulation 207
# Running simulations for SB radius 0.84 mm, simulation 208
# Running simulations for SB radius 0.91 mm, simulation 209
# Running simulations for SB radius 1.08 mm, simulation 210
# Running simulations for SB radius 1.11 mm, simulation 211
# Running simulations for SB radius 1.48 mm, simulation 212
# Running simulations for SB radius 1.29 mm, simulation 213
# Running simulations for SB radius 0.49 mm, simulation 214
# Running simulations for SB radius 0.76 mm, simulation 215
# Running simulations for SB radius 1.86 mm, simulation 216
# Running simulations for SB radius 0.74 mm, simulation 217
# Running simulations for SB radius 1.48 mm, simulation 218
# Running simulations for SB radius 1.43 mm, simulation 219
# Running simulations for SB radius 1.91 mm, simulation 220
# Running simulations for SB radius 1.66 mm, simulation 221
# Running simulations for SB radius 0.88 mm, simulation 222
# Running simulations for SB radius 1.11 mm, simulation 223
# Running simulations for SB radius 1.32 mm, simulation 224
# Running simulations for SB radius 0.96 mm, simulation 225
# Running simulations for SB radius 0.58 mm, simulation 226
# Running simulations for SB radius 1.11 mm, simulation 227
# Running simulations for SB radius 0.24 mm, simulation 228
# Running simulations for SB radius 1.89 mm, simulation 229
# Running simulations for SB radius 0.45 mm, simulation 230
# Running simulations for SB radius 2.32 mm, simulation 231
# Running simulations for SB radius 0.81 mm, simulation 232
# Running simulations for SB radius 1.53 mm, simulation 233
# Running simulations for SB radius 1.04 mm, simulation 234
# Running simulations for SB radius 0.75 mm, simulation 235
# Running simulations for SB radius 0.89 mm, simulation 236
# Running simulations for SB radius 1.79 mm, simulation 237
# Running simulations for SB radius 1.31 mm, simulation 238
# Running simulations for SB radius 0.80 mm, simulation 239
# Running simulations for SB radius 0.61 mm, simulation 240
# Running simulations for SB radius 2.06 mm, simulation 241
# Running simulations for SB radius 1.00 mm, simulation 242
# Running simulations for SB radius 1.37 mm, simulation 243
# Running simulations for SB radius 0.90 mm, simulation 244
# Running simulations for SB radius 1.53 mm, simulation 245
# Running simulations for SB radius 1.39 mm, simulation 246
# Running simulations for SB radius 1.71 mm, simulation 247
# Running simulations for SB radius 1.07 mm, simulation 248
# Running simulations for SB radius 0.72 mm, simulation 249
# Running simulations for SB radius 0.77 mm, simulation 250
# Running simulations for SB radius 0.70 mm, simulation 251
# Running simulations for SB radius 0.45 mm, simulation 252
# Running simulations for SB radius 0.67 mm, simulation 253
# Running simulations for SB radius 1.88 mm, simulation 254
# Running simulations for SB radius 2.56 mm, simulation 255
# Running simulations for SB radius 1.27 mm, simulation 256
# Running simulations for SB radius 1.03 mm, simulation 257
# Running simulations for SB radius 1.94 mm, simulation 258
# Running simulations for SB radius 1.47 mm, simulation 259
# Running simulations for SB radius 0.60 mm, simulation 260
# Running simulations for SB radius 1.25 mm, simulation 261
# Running simulations for SB radius 1.67 mm, simulation 262
# Running simulations for SB radius 1.13 mm, simulation 263
# Running simulations for SB radius 1.40 mm, simulation 264
# Running simulations for SB radius 1.12 mm, simulation 265
# Running simulations for SB radius 0.95 mm, simulation 266
# Running simulations for SB radius 2.29 mm, simulation 267
# Running simulations for SB radius 2.48 mm, simulation 268
# Running simulations for SB radius 0.92 mm, simulation 269
# Running simulations for SB radius 0.83 mm, simulation 270
# Running simulations for SB radius 1.05 mm, simulation 271
# Running simulations for SB radius 1.17 mm, simulation 272
# Running simulations for SB radius 0.58 mm, simulation 273
# Running simulations for SB radius 0.95 mm, simulation 274
# Running simulations for SB radius 0.79 mm, simulation 275
# Running simulations for SB radius 0.52 mm, simulation 276
# Running simulations for SB radius 1.11 mm, simulation 277
# Running simulations for SB radius 1.15 mm, simulation 278
# Running simulations for SB radius 0.64 mm, simulation 279
# Running simulations for SB radius 0.97 mm, simulation 280
# Running simulations for SB radius 0.62 mm, simulation 281
# Running simulations for SB radius 0.90 mm, simulation 282
# Running simulations for SB radius 0.73 mm, simulation 283
# Running simulations for SB radius 1.12 mm, simulation 284
# Running simulations for SB radius 0.94 mm, simulation 285
# Running simulations for SB radius 1.68 mm, simulation 286
# Running simulations for SB radius 1.55 mm, simulation 287
# Running simulations for SB radius 1.39 mm, simulation 288
# Running simulations for SB radius 0.93 mm, simulation 289
# Running simulations for SB radius 1.06 mm, simulation 290
# Running simulations for SB radius 1.45 mm, simulation 291
# Running simulations for SB radius 0.91 mm, simulation 292
# Running simulations for SB radius 1.06 mm, simulation 293
# Running simulations for SB radius 1.25 mm, simulation 294
# Running simulations for SB radius 0.79 mm, simulation 295
# Running simulations for SB radius 1.76 mm, simulation 296
# Running simulations for SB radius 0.85 mm, simulation 297
# Running simulations for SB radius 1.14 mm, simulation 298
# Running simulations for SB radius 1.12 mm, simulation 299
# Running simulations for SB radius 0.70 mm, simulation 300
# Running simulations for SB radius 1.09 mm, simulation 301
# Running simulations for SB radius 0.83 mm, simulation 302
# Running simulations for SB radius 0.83 mm, simulation 303
# Running simulations for SB radius 1.85 mm, simulation 304
# Running simulations for SB radius 1.59 mm, simulation 305
# Running simulations for SB radius 0.94 mm, simulation 306
# Running simulations for SB radius 0.64 mm, simulation 307
# Running simulations for SB radius 0.36 mm, simulation 308
# Running simulations for SB radius 1.05 mm, simulation 309
# Running simulations for SB radius 1.06 mm, simulation 310
# Running simulations for SB radius 0.48 mm, simulation 311
# Running simulations for SB radius 1.12 mm, simulation 312
# Running simulations for SB radius 1.06 mm, simulation 313
# Running simulations for SB radius 1.58 mm, simulation 314
# Running simulations for SB radius 1.64 mm, simulation 315
# Running simulations for SB radius 0.61 mm, simulation 316
# Running simulations for SB radius 1.00 mm, simulation 317
# Running simulations for SB radius 0.66 mm, simulation 318
# Running simulations for SB radius 1.07 mm, simulation 319
# Running simulations for SB radius 0.50 mm, simulation 320
# Running simulations for SB radius 1.04 mm, simulation 321
# Running simulations for SB radius 1.63 mm, simulation 322
# Running simulations for SB radius 1.25 mm, simulation 323
# Running simulations for SB radius 1.64 mm, simulation 324
# Running simulations for SB radius 1.05 mm, simulation 325
# Running simulations for SB radius 1.36 mm, simulation 326
# Running simulations for SB radius 0.79 mm, simulation 327
# Running simulations for SB radius 1.73 mm, simulation 328
# Running simulations for SB radius 1.01 mm, simulation 329
# Running simulations for SB radius 0.74 mm, simulation 330
# Running simulations for SB radius 0.96 mm, simulation 331
# Running simulations for SB radius 1.85 mm, simulation 332
# Running simulations for SB radius 0.48 mm, simulation 333
# Running simulations for SB radius 1.27 mm, simulation 334
# Running simulations for SB radius 1.11 mm, simulation 335
# Running simulations for SB radius 1.59 mm, simulation 336
# Running simulations for SB radius 0.55 mm, simulation 337
# Running simulations for SB radius 0.90 mm, simulation 338
# Running simulations for SB radius 0.80 mm, simulation 339
# Running simulations for SB radius 1.10 mm, simulation 340
# Running simulations for SB radius 1.24 mm, simulation 341
# Running simulations for SB radius 1.60 mm, simulation 342
# Running simulations for SB radius 1.16 mm, simulation 343
# Running simulations for SB radius 1.16 mm, simulation 344
# Running simulations for SB radius 1.56 mm, simulation 345
# Running simulations for SB radius 1.46 mm, simulation 346
# Running simulations for SB radius 0.74 mm, simulation 347
# Running simulations for SB radius 0.54 mm, simulation 348
# Running simulations for SB radius 1.08 mm, simulation 349
# Running simulations for SB radius 1.57 mm, simulation 350
# Running simulations for SB radius 0.49 mm, simulation 351
# Running simulations for SB radius 0.89 mm, simulation 352
# Running simulations for SB radius 1.22 mm, simulation 353
# Running simulations for SB radius 0.63 mm, simulation 354
# Running simulations for SB radius 0.72 mm, simulation 355
# Running simulations for SB radius 1.41 mm, simulation 356
# Running simulations for SB radius 1.86 mm, simulation 357
# Running simulations for SB radius 1.29 mm, simulation 358
# Running simulations for SB radius 1.08 mm, simulation 359
# Running simulations for SB radius 0.62 mm, simulation 360
# Running simulations for SB radius 2.53 mm, simulation 361
# Running simulations for SB radius 0.70 mm, simulation 362
# Running simulations for SB radius 1.00 mm, simulation 363
# Running simulations for SB radius 0.51 mm, simulation 364
# Running simulations for SB radius 0.98 mm, simulation 365
# Running simulations for SB radius 0.60 mm, simulation 366
# Running simulations for SB radius 2.91 mm, simulation 367
# Running simulations for SB radius 1.46 mm, simulation 368
# Running simulations for SB radius 0.79 mm, simulation 369
# Running simulations for SB radius 2.36 mm, simulation 370
# Running simulations for SB radius 1.42 mm, simulation 371
# Running simulations for SB radius 1.90 mm, simulation 372
# Running simulations for SB radius 0.82 mm, simulation 373
# Running simulations for SB radius 1.31 mm, simulation 374
# Running simulations for SB radius 1.27 mm, simulation 375
# Running simulations for SB radius 1.83 mm, simulation 376
# Running simulations for SB radius 1.82 mm, simulation 377
# Running simulations for SB radius 0.73 mm, simulation 378
# Running simulations for SB radius 0.51 mm, simulation 379
# Running simulations for SB radius 1.81 mm, simulation 380
# Running simulations for SB radius 0.85 mm, simulation 381
# Running simulations for SB radius 1.12 mm, simulation 382
# Running simulations for SB radius 0.28 mm, simulation 383
# Running simulations for SB radius 2.12 mm, simulation 384
# Running simulations for SB radius 1.02 mm, simulation 385
# Running simulations for SB radius 1.07 mm, simulation 386
# Running simulations for SB radius 0.89 mm, simulation 387
# Running simulations for SB radius 0.48 mm, simulation 388
# Running simulations for SB radius 0.70 mm, simulation 389
# Running simulations for SB radius 1.55 mm, simulation 390
# Running simulations for SB radius 2.05 mm, simulation 391
# Running simulations for SB radius 2.43 mm, simulation 392
# Running simulations for SB radius 2.32 mm, simulation 393
# Running simulations for SB radius 0.36 mm, simulation 394
# Running simulations for SB radius 1.52 mm, simulation 395
# Running simulations for SB radius 0.41 mm, simulation 396
# Running simulations for SB radius 1.37 mm, simulation 397
# Running simulations for SB radius 1.11 mm, simulation 398
# Running simulations for SB radius 0.83 mm, simulation 399
# Running simulations for SB radius 0.90 mm, simulation 400
# Running simulations for SB radius 1.40 mm, simulation 401
# Running simulations for SB radius 1.20 mm, simulation 402
# Running simulations for SB radius 0.75 mm, simulation 403
# Running simulations for SB radius 1.90 mm, simulation 404
# Running simulations for SB radius 0.55 mm, simulation 405
# Running simulations for SB radius 0.71 mm, simulation 406
# Running simulations for SB radius 1.49 mm, simulation 407
# Running simulations for SB radius 1.00 mm, simulation 408
# Running simulations for SB radius 1.13 mm, simulation 409
# Running simulations for SB radius 0.84 mm, simulation 410
# Running simulations for SB radius 2.00 mm, simulation 411
# Running simulations for SB radius 0.45 mm, simulation 412
# Running simulations for SB radius 1.29 mm, simulation 413
# Running simulations for SB radius 1.13 mm, simulation 414
# Running simulations for SB radius 1.01 mm, simulation 415
# Running simulations for SB radius 0.35 mm, simulation 416
# Running simulations for SB radius 0.85 mm, simulation 417
# Running simulations for SB radius 1.37 mm, simulation 418
# Running simulations for SB radius 0.83 mm, simulation 419
# Running simulations for SB radius 0.87 mm, simulation 420
# Running simulations for SB radius 1.52 mm, simulation 421
# Running simulations for SB radius 1.56 mm, simulation 422
# Running simulations for SB radius 2.71 mm, simulation 423
# Running simulations for SB radius 0.59 mm, simulation 424
# Running simulations for SB radius 0.84 mm, simulation 425
# Running simulations for SB radius 0.81 mm, simulation 426
# Running simulations for SB radius 0.59 mm, simulation 427
# Running simulations for SB radius 1.19 mm, simulation 428
# Running simulations for SB radius 1.07 mm, simulation 429
# Running simulations for SB radius 1.27 mm, simulation 430
# Running simulations for SB radius 1.24 mm, simulation 431
# Running simulations for SB radius 0.91 mm, simulation 432
# Running simulations for SB radius 1.03 mm, simulation 433
# Running simulations for SB radius 0.91 mm, simulation 434
# Running simulations for SB radius 1.45 mm, simulation 435
# Running simulations for SB radius 0.45 mm, simulation 436
# Running simulations for SB radius 1.01 mm, simulation 437
# Running simulations for SB radius 0.93 mm, simulation 438
# Running simulations for SB radius 0.65 mm, simulation 439
# Running simulations for SB radius 0.82 mm, simulation 440
# Running simulations for SB radius 2.64 mm, simulation 441
# Running simulations for SB radius 1.35 mm, simulation 442
# Running simulations for SB radius 0.98 mm, simulation 443
# Running simulations for SB radius 0.52 mm, simulation 444
# Running simulations for SB radius 0.77 mm, simulation 445
# Running simulations for SB radius 0.35 mm, simulation 446
# Running simulations for SB radius 0.48 mm, simulation 447
# Running simulations for SB radius 0.69 mm, simulation 448
# Running simulations for SB radius 1.04 mm, simulation 449
# Running simulations for SB radius 1.32 mm, simulation 450
# Running simulations for SB radius 1.99 mm, simulation 451
# Running simulations for SB radius 1.49 mm, simulation 452
# Running simulations for SB radius 0.32 mm, simulation 453
# Running simulations for SB radius 0.63 mm, simulation 454
# Running simulations for SB radius 1.31 mm, simulation 455
# Running simulations for SB radius 1.43 mm, simulation 456
# Running simulations for SB radius 1.28 mm, simulation 457
# Running simulations for SB radius 1.07 mm, simulation 458
# Running simulations for SB radius 0.28 mm, simulation 459
# Running simulations for SB radius 0.96 mm, simulation 460
# Running simulations for SB radius 1.37 mm, simulation 461
# Running simulations for SB radius 1.15 mm, simulation 462
# Running simulations for SB radius 0.68 mm, simulation 463
# Running simulations for SB radius 2.32 mm, simulation 464
# Running simulations for SB radius 0.88 mm, simulation 465
# Running simulations for SB radius 0.79 mm, simulation 466
# Running simulations for SB radius 0.29 mm, simulation 467
# Running simulations for SB radius 0.62 mm, simulation 468
# Running simulations for SB radius 0.81 mm, simulation 469
# Running simulations for SB radius 0.73 mm, simulation 470
# Running simulations for SB radius 0.77 mm, simulation 471
# Running simulations for SB radius 0.89 mm, simulation 472
# Running simulations for SB radius 1.03 mm, simulation 473
# Running simulations for SB radius 0.47 mm, simulation 474
# Running simulations for SB radius 0.95 mm, simulation 475
# Running simulations for SB radius 0.70 mm, simulation 476
# Running simulations for SB radius 1.69 mm, simulation 477
# Running simulations for SB radius 0.87 mm, simulation 478
# Running simulations for SB radius 2.57 mm, simulation 479
# Running simulations for SB radius 1.29 mm, simulation 480
# Running simulations for SB radius 1.15 mm, simulation 481
# Running simulations for SB radius 1.50 mm, simulation 482
# Running simulations for SB radius 2.23 mm, simulation 483
# Running simulations for SB radius 0.74 mm, simulation 484
# Running simulations for SB radius 2.92 mm, simulation 485
# Running simulations for SB radius 1.77 mm, simulation 486
# Running simulations for SB radius 0.50 mm, simulation 487
# Running simulations for SB radius 1.35 mm, simulation 488
# Running simulations for SB radius 0.74 mm, simulation 489
# Running simulations for SB radius 1.35 mm, simulation 490
# Running simulations for SB radius 1.32 mm, simulation 491
# Running simulations for SB radius 1.11 mm, simulation 492
# Running simulations for SB radius 1.10 mm, simulation 493
# Running simulations for SB radius 0.61 mm, simulation 494
# Running simulations for SB radius 1.77 mm, simulation 495
# Running simulations for SB radius 1.17 mm, simulation 496
# Running simulations for SB radius 1.24 mm, simulation 497
# Running simulations for SB radius 0.64 mm, simulation 498
# Running simulations for SB radius 1.04 mm, simulation 499
# Running simulations for SB radius 1.24 mm, simulation 500
# Running simulations for SB radius 0.93 mm, simulation 501
# Running simulations for SB radius 0.44 mm, simulation 502
# Running simulations for SB radius 1.47 mm, simulation 503
# Running simulations for SB radius 1.49 mm, simulation 504
# Running simulations for SB radius 0.69 mm, simulation 505
# Running simulations for SB radius 1.08 mm, simulation 506
# Running simulations for SB radius 1.06 mm, simulation 507
# Running simulations for SB radius 0.22 mm, simulation 508
# Running simulations for SB radius 0.85 mm, simulation 509
# Running simulations for SB radius 1.15 mm, simulation 510
# Running simulations for SB radius 1.16 mm, simulation 511
# Running simulations for SB radius 1.09 mm, simulation 512
# Running simulations for SB radius 0.98 mm, simulation 513
# Running simulations for SB radius 0.83 mm, simulation 514
# Running simulations for SB radius 1.07 mm, simulation 515
# Running simulations for SB radius 1.00 mm, simulation 516
# Running simulations for SB radius 0.71 mm, simulation 517
# Running simulations for SB radius 0.87 mm, simulation 518
# Running simulations for SB radius 0.93 mm, simulation 519
# Running simulations for SB radius 0.98 mm, simulation 520
# Running simulations for SB radius 0.99 mm, simulation 521
# Running simulations for SB radius 1.15 mm, simulation 522
# Running simulations for SB radius 1.17 mm, simulation 523
# Running simulations for SB radius 0.62 mm, simulation 524
# Running simulations for SB radius 1.16 mm, simulation 525
# Running simulations for SB radius 1.45 mm, simulation 526
# Running simulations for SB radius 1.19 mm, simulation 527
# Running simulations for SB radius 1.32 mm, simulation 528
# Running simulations for SB radius 0.88 mm, simulation 529
# Running simulations for SB radius 1.74 mm, simulation 530
# Running simulations for SB radius 0.90 mm, simulation 531
# Running simulations for SB radius 2.13 mm, simulation 532
# Running simulations for SB radius 0.68 mm, simulation 533
# Running simulations for SB radius 0.93 mm, simulation 534
# Running simulations for SB radius 1.97 mm, simulation 535
# Running simulations for SB radius 0.71 mm, simulation 536
# Running simulations for SB radius 0.90 mm, simulation 537
# Running simulations for SB radius 1.37 mm, simulation 538
# Running simulations for SB radius 1.35 mm, simulation 539
# Running simulations for SB radius 0.22 mm, simulation 540
# Running simulations for SB radius 1.05 mm, simulation 541
# Running simulations for SB radius 0.40 mm, simulation 542
# Running simulations for SB radius 1.61 mm, simulation 543
# Running simulations for SB radius 1.26 mm, simulation 544
# Running simulations for SB radius 1.40 mm, simulation 545
# Running simulations for SB radius 1.21 mm, simulation 546
# Running simulations for SB radius 0.57 mm, simulation 547
# Running simulations for SB radius 0.28 mm, simulation 548
# Running simulations for SB radius 1.74 mm, simulation 549
# Running simulations for SB radius 1.24 mm, simulation 550
# Running simulations for SB radius 1.98 mm, simulation 551
# Running simulations for SB radius 0.42 mm, simulation 552
# Running simulations for SB radius 0.70 mm, simulation 553
# Running simulations for SB radius 1.41 mm, simulation 554
# Running simulations for SB radius 0.67 mm, simulation 555
# Running simulations for SB radius 1.82 mm, simulation 556
# Running simulations for SB radius 1.23 mm, simulation 557
# Running simulations for SB radius 0.70 mm, simulation 558
# Running simulations for SB radius 0.51 mm, simulation 559
# Running simulations for SB radius 1.26 mm, simulation 560
# Running simulations for SB radius 1.14 mm, simulation 561
# Running simulations for SB radius 1.38 mm, simulation 562
# Running simulations for SB radius 0.79 mm, simulation 563
# Running simulations for SB radius 0.53 mm, simulation 564
# Running simulations for SB radius 0.92 mm, simulation 565
# Running simulations for SB radius 0.87 mm, simulation 566
# Running simulations for SB radius 1.37 mm, simulation 567
# Running simulations for SB radius 0.87 mm, simulation 568
# Running simulations for SB radius 1.64 mm, simulation 569
# Running simulations for SB radius 0.40 mm, simulation 570
# Running simulations for SB radius 2.08 mm, simulation 571
# Running simulations for SB radius 1.04 mm, simulation 572
# Running simulations for SB radius 1.28 mm, simulation 573
# Running simulations for SB radius 1.58 mm, simulation 574
# Running simulations for SB radius 1.31 mm, simulation 575
# Running simulations for SB radius 1.07 mm, simulation 576
# Running simulations for SB radius 1.96 mm, simulation 577
# Running simulations for SB radius 1.35 mm, simulation 578
# Running simulations for SB radius 1.24 mm, simulation 579
# Running simulations for SB radius 1.40 mm, simulation 580
# Running simulations for SB radius 2.31 mm, simulation 581
# Running simulations for SB radius 1.44 mm, simulation 582
# Running simulations for SB radius 1.33 mm, simulation 583
# Running simulations for SB radius 0.74 mm, simulation 584
# Running simulations for SB radius 0.87 mm, simulation 585
# Running simulations for SB radius 0.58 mm, simulation 586
# Running simulations for SB radius 1.30 mm, simulation 587
# Running simulations for SB radius 0.42 mm, simulation 588
# Running simulations for SB radius 0.70 mm, simulation 589
# Running simulations for SB radius 1.76 mm, simulation 590
# Running simulations for SB radius 1.79 mm, simulation 591
# Running simulations for SB radius 0.95 mm, simulation 592
# Running simulations for SB radius 1.16 mm, simulation 593
# Running simulations for SB radius 1.64 mm, simulation 594
# Running simulations for SB radius 0.81 mm, simulation 595
# Running simulations for SB radius 0.93 mm, simulation 596
# Running simulations for SB radius 1.20 mm, simulation 597
# Running simulations for SB radius 2.05 mm, simulation 598
# Running simulations for SB radius 0.41 mm, simulation 599
# Running simulations for SB radius 1.51 mm, simulation 600
# Running simulations for SB radius 0.70 mm, simulation 601
# Running simulations for SB radius 1.56 mm, simulation 602
# Running simulations for SB radius 2.07 mm, simulation 603
# Running simulations for SB radius 1.08 mm, simulation 604
# Running simulations for SB radius 0.45 mm, simulation 605
# Running simulations for SB radius 1.74 mm, simulation 606
# Running simulations for SB radius 0.60 mm, simulation 607
# Running simulations for SB radius 0.49 mm, simulation 608
# Running simulations for SB radius 0.96 mm, simulation 609
# Running simulations for SB radius 0.92 mm, simulation 610
# Running simulations for SB radius 2.09 mm, simulation 611
# Running simulations for SB radius 1.93 mm, simulation 612
# Running simulations for SB radius 0.36 mm, simulation 613
# Running simulations for SB radius 1.00 mm, simulation 614
# Running simulations for SB radius 1.31 mm, simulation 615
# Running simulations for SB radius 1.40 mm, simulation 616
# Running simulations for SB radius 1.47 mm, simulation 617
# Running simulations for SB radius 1.34 mm, simulation 618
# Running simulations for SB radius 0.64 mm, simulation 619
# Running simulations for SB radius 2.38 mm, simulation 620
# Running simulations for SB radius 1.96 mm, simulation 621
# Running simulations for SB radius 0.80 mm, simulation 622
# Running simulations for SB radius 0.99 mm, simulation 623
# Running simulations for SB radius 1.59 mm, simulation 624
# Running simulations for SB radius 1.00 mm, simulation 625
# Running simulations for SB radius 0.89 mm, simulation 626
# Running simulations for SB radius 1.29 mm, simulation 627
# Running simulations for SB radius 0.91 mm, simulation 628
# Running simulations for SB radius 0.92 mm, simulation 629
# Running simulations for SB radius 1.13 mm, simulation 630
# Running simulations for SB radius 1.29 mm, simulation 631
# Running simulations for SB radius 0.97 mm, simulation 632
# Running simulations for SB radius 1.89 mm, simulation 633
# Running simulations for SB radius 0.62 mm, simulation 634
# Running simulations for SB radius 0.82 mm, simulation 635
# Running simulations for SB radius 0.71 mm, simulation 636
# Running simulations for SB radius 1.52 mm, simulation 637
# Running simulations for SB radius 0.79 mm, simulation 638
# Running simulations for SB radius 1.72 mm, simulation 639
# Running simulations for SB radius 2.03 mm, simulation 640
# Running simulations for SB radius 0.79 mm, simulation 641
# Running simulations for SB radius 1.41 mm, simulation 642
# Running simulations for SB radius 0.57 mm, simulation 643
# Running simulations for SB radius 0.57 mm, simulation 644
# Running simulations for SB radius 0.67 mm, simulation 645
# Running simulations for SB radius 1.63 mm, simulation 646
# Running simulations for SB radius 1.18 mm, simulation 647
# Running simulations for SB radius 0.98 mm, simulation 648
# Running simulations for SB radius 1.80 mm, simulation 649
# Running simulations for SB radius 0.69 mm, simulation 650
# Running simulations for SB radius 2.30 mm, simulation 651
# Running simulations for SB radius 0.60 mm, simulation 652
# Running simulations for SB radius 0.61 mm, simulation 653
# Running simulations for SB radius 0.94 mm, simulation 654
# Running simulations for SB radius 1.16 mm, simulation 655
# Running simulations for SB radius 0.89 mm, simulation 656
# Running simulations for SB radius 0.56 mm, simulation 657
# Running simulations for SB radius 0.86 mm, simulation 658
# Running simulations for SB radius 0.91 mm, simulation 659
# Running simulations for SB radius 0.60 mm, simulation 660
# Running simulations for SB radius 0.58 mm, simulation 661
# Running simulations for SB radius 1.01 mm, simulation 662
# Running simulations for SB radius 0.98 mm, simulation 663
# Running simulations for SB radius 2.26 mm, simulation 664
# Running simulations for SB radius 1.26 mm, simulation 665
# Running simulations for SB radius 1.55 mm, simulation 666
# Running simulations for SB radius 1.49 mm, simulation 667
# Running simulations for SB radius 0.90 mm, simulation 668
# Running simulations for SB radius 0.97 mm, simulation 669
# Running simulations for SB radius 1.51 mm, simulation 670
# Running simulations for SB radius 0.36 mm, simulation 671
# Running simulations for SB radius 1.03 mm, simulation 672
# Running simulations for SB radius 1.22 mm, simulation 673
# Running simulations for SB radius 2.29 mm, simulation 674
# Running simulations for SB radius 0.81 mm, simulation 675
# Running simulations for SB radius 1.61 mm, simulation 676
# Running simulations for SB radius 1.26 mm, simulation 677
# Running simulations for SB radius 0.67 mm, simulation 678
# Running simulations for SB radius 1.19 mm, simulation 679
# Running simulations for SB radius 0.83 mm, simulation 680
# Running simulations for SB radius 0.59 mm, simulation 681
# Running simulations for SB radius 1.50 mm, simulation 682
# Running simulations for SB radius 1.53 mm, simulation 683
# Running simulations for SB radius 0.51 mm, simulation 684
# Running simulations for SB radius 1.34 mm, simulation 685
# Running simulations for SB radius 1.36 mm, simulation 686
# Running simulations for SB radius 1.17 mm, simulation 687
# Running simulations for SB radius 0.62 mm, simulation 688
# Running simulations for SB radius 1.37 mm, simulation 689
# Running simulations for SB radius 1.76 mm, simulation 690
# Running simulations for SB radius 1.40 mm, simulation 691
# Running simulations for SB radius 1.29 mm, simulation 692
# Running simulations for SB radius 0.84 mm, simulation 693
# Running simulations for SB radius 0.56 mm, simulation 694
# Running simulations for SB radius 1.02 mm, simulation 695
# Running simulations for SB radius 1.29 mm, simulation 696
# Running simulations for SB radius 1.26 mm, simulation 697
# Running simulations for SB radius 0.48 mm, simulation 698
# Running simulations for SB radius 0.57 mm, simulation 699
# Running simulations for SB radius 0.64 mm, simulation 700
# Running simulations for SB radius 0.53 mm, simulation 701
# Running simulations for SB radius 1.13 mm, simulation 702
# Running simulations for SB radius 0.68 mm, simulation 703
# Running simulations for SB radius 0.75 mm, simulation 704
# Running simulations for SB radius 0.87 mm, simulation 705
# Running simulations for SB radius 0.49 mm, simulation 706
# Running simulations for SB radius 1.35 mm, simulation 707
# Running simulations for SB radius 1.91 mm, simulation 708
# Running simulations for SB radius 0.49 mm, simulation 709
# Running simulations for SB radius 0.87 mm, simulation 710
# Running simulations for SB radius 1.92 mm, simulation 711
# Running simulations for SB radius 1.67 mm, simulation 712
# Running simulations for SB radius 1.15 mm, simulation 713
# Running simulations for SB radius 2.10 mm, simulation 714
# Running simulations for SB radius 0.55 mm, simulation 715
# Running simulations for SB radius 1.45 mm, simulation 716
# Running simulations for SB radius 1.42 mm, simulation 717
# Running simulations for SB radius 0.98 mm, simulation 718
# Running simulations for SB radius 0.99 mm, simulation 719
# Running simulations for SB radius 0.83 mm, simulation 720
# Running simulations for SB radius 0.96 mm, simulation 721
# Running simulations for SB radius 1.31 mm, simulation 722
# Running simulations for SB radius 0.83 mm, simulation 723
# Running simulations for SB radius 1.67 mm, simulation 724
# Running simulations for SB radius 0.85 mm, simulation 725
# Running simulations for SB radius 0.74 mm, simulation 726
# Running simulations for SB radius 0.87 mm, simulation 727
# Running simulations for SB radius 1.14 mm, simulation 728
# Running simulations for SB radius 0.63 mm, simulation 729
# Running simulations for SB radius 0.92 mm, simulation 730
# Running simulations for SB radius 0.69 mm, simulation 731
# Running simulations for SB radius 1.08 mm, simulation 732
# Running simulations for SB radius 0.84 mm, simulation 733
# Running simulations for SB radius 1.29 mm, simulation 734
# Running simulations for SB radius 0.51 mm, simulation 735
# Running simulations for SB radius 0.96 mm, simulation 736
# Running simulations for SB radius 0.84 mm, simulation 737
# Running simulations for SB radius 1.31 mm, simulation 738
# Running simulations for SB radius 1.15 mm, simulation 739
# Running simulations for SB radius 1.12 mm, simulation 740
# Running simulations for SB radius 0.86 mm, simulation 741
# Running simulations for SB radius 1.02 mm, simulation 742
# Running simulations for SB radius 2.06 mm, simulation 743
# Running simulations for SB radius 0.90 mm, simulation 744
# Running simulations for SB radius 1.09 mm, simulation 745
# Running simulations for SB radius 1.47 mm, simulation 746
# Running simulations for SB radius 0.66 mm, simulation 747
# Running simulations for SB radius 1.96 mm, simulation 748
# Running simulations for SB radius 2.26 mm, simulation 749
# Running simulations for SB radius 0.49 mm, simulation 750
# Running simulations for SB radius 1.61 mm, simulation 751
# Running simulations for SB radius 1.02 mm, simulation 752
# Running simulations for SB radius 1.71 mm, simulation 753
# Running simulations for SB radius 1.72 mm, simulation 754
# Running simulations for SB radius 1.61 mm, simulation 755
# Running simulations for SB radius 1.93 mm, simulation 756
# Running simulations for SB radius 1.04 mm, simulation 757
# Running simulations for SB radius 1.33 mm, simulation 758
# Running simulations for SB radius 1.06 mm, simulation 759
# Running simulations for SB radius 0.61 mm, simulation 760
# Running simulations for SB radius 1.75 mm, simulation 761
# Running simulations for SB radius 1.13 mm, simulation 762
# Running simulations for SB radius 1.57 mm, simulation 763
# Running simulations for SB radius 1.43 mm, simulation 764
# Running simulations for SB radius 2.54 mm, simulation 765
# Running simulations for SB radius 1.28 mm, simulation 766
# Running simulations for SB radius 1.17 mm, simulation 767
# Running simulations for SB radius 1.13 mm, simulation 768
# Running simulations for SB radius 1.98 mm, simulation 769
# Running simulations for SB radius 1.73 mm, simulation 770
# Running simulations for SB radius 2.26 mm, simulation 771
# Running simulations for SB radius 0.66 mm, simulation 772
# Running simulations for SB radius 0.93 mm, simulation 773
# Running simulations for SB radius 1.52 mm, simulation 774
# Running simulations for SB radius 1.11 mm, simulation 775
# Running simulations for SB radius 1.75 mm, simulation 776
# Running simulations for SB radius 1.16 mm, simulation 777
# Running simulations for SB radius 1.11 mm, simulation 778
# Running simulations for SB radius 1.15 mm, simulation 779
# Running simulations for SB radius 1.71 mm, simulation 780
# Running simulations for SB radius 0.51 mm, simulation 781
# Running simulations for SB radius 0.55 mm, simulation 782
# Running simulations for SB radius 1.33 mm, simulation 783
# Running simulations for SB radius 1.80 mm, simulation 784
# Running simulations for SB radius 1.24 mm, simulation 785
# Running simulations for SB radius 0.90 mm, simulation 786
# Running simulations for SB radius 1.06 mm, simulation 787
# Running simulations for SB radius 2.66 mm, simulation 788
# Running simulations for SB radius 0.83 mm, simulation 789
# Running simulations for SB radius 0.80 mm, simulation 790
# Running simulations for SB radius 1.10 mm, simulation 791
# Running simulations for SB radius 1.18 mm, simulation 792
# Running simulations for SB radius 1.22 mm, simulation 793
# Running simulations for SB radius 1.23 mm, simulation 794
# Running simulations for SB radius 1.31 mm, simulation 795
# Running simulations for SB radius 0.68 mm, simulation 796
# Running simulations for SB radius 1.27 mm, simulation 797
# Running simulations for SB radius 0.85 mm, simulation 798
# Running simulations for SB radius 1.70 mm, simulation 799
# Running simulations for SB radius 1.29 mm, simulation 800
# Running simulations for SB radius 1.53 mm, simulation 801
# Running simulations for SB radius 1.63 mm, simulation 802
# Running simulations for SB radius 0.98 mm, simulation 803
# Running simulations for SB radius 0.59 mm, simulation 804
# Running simulations for SB radius 1.09 mm, simulation 805
# Running simulations for SB radius 1.25 mm, simulation 806
# Running simulations for SB radius 0.21 mm, simulation 807
# Running simulations for SB radius 0.96 mm, simulation 808
# Running simulations for SB radius 1.24 mm, simulation 809
# Running simulations for SB radius 0.74 mm, simulation 810
# Running simulations for SB radius 1.72 mm, simulation 811
# Running simulations for SB radius 1.40 mm, simulation 812
# Running simulations for SB radius 2.02 mm, simulation 813
# Running simulations for SB radius 1.54 mm, simulation 814
# Running simulations for SB radius 0.77 mm, simulation 815
# Running simulations for SB radius 0.86 mm, simulation 816
# Running simulations for SB radius 0.98 mm, simulation 817
# Running simulations for SB radius 1.85 mm, simulation 818
# Running simulations for SB radius 1.57 mm, simulation 819
# Running simulations for SB radius 0.64 mm, simulation 820
# Running simulations for SB radius 1.48 mm, simulation 821
# Running simulations for SB radius 0.96 mm, simulation 822
# Running simulations for SB radius 1.29 mm, simulation 823
# Running simulations for SB radius 1.06 mm, simulation 824
# Running simulations for SB radius 1.06 mm, simulation 825
# Running simulations for SB radius 0.97 mm, simulation 826
# Running simulations for SB radius 1.06 mm, simulation 827
# Running simulations for SB radius 1.15 mm, simulation 828
# Running simulations for SB radius 1.36 mm, simulation 829
# Running simulations for SB radius 0.91 mm, simulation 830
# Running simulations for SB radius 1.37 mm, simulation 831
# Running simulations for SB radius 2.35 mm, simulation 832
# Running simulations for SB radius 0.69 mm, simulation 833
# Running simulations for SB radius 0.92 mm, simulation 834
# Running simulations for SB radius 1.26 mm, simulation 835
# Running simulations for SB radius 0.93 mm, simulation 836
# Running simulations for SB radius 0.62 mm, simulation 837
# Running simulations for SB radius 1.12 mm, simulation 838
# Running simulations for SB radius 1.11 mm, simulation 839
# Running simulations for SB radius 0.43 mm, simulation 840
# Running simulations for SB radius 1.25 mm, simulation 841
# Running simulations for SB radius 1.85 mm, simulation 842
# Running simulations for SB radius 1.15 mm, simulation 843
# Running simulations for SB radius 0.78 mm, simulation 844
# Running simulations for SB radius 1.33 mm, simulation 845
# Running simulations for SB radius 1.03 mm, simulation 846
# Running simulations for SB radius 0.95 mm, simulation 847
# Running simulations for SB radius 1.06 mm, simulation 848
# Running simulations for SB radius 0.54 mm, simulation 849
# Running simulations for SB radius 1.36 mm, simulation 850
# Running simulations for SB radius 1.38 mm, simulation 851
# Running simulations for SB radius 1.02 mm, simulation 852
# Running simulations for SB radius 1.75 mm, simulation 853
# Running simulations for SB radius 1.73 mm, simulation 854
# Running simulations for SB radius 1.19 mm, simulation 855
# Running simulations for SB radius 1.21 mm, simulation 856
# Running simulations for SB radius 0.91 mm, simulation 857
# Running simulations for SB radius 1.61 mm, simulation 858
# Running simulations for SB radius 1.01 mm, simulation 859
# Running simulations for SB radius 1.12 mm, simulation 860
# Running simulations for SB radius 0.78 mm, simulation 861
# Running simulations for SB radius 1.11 mm, simulation 862
# Running simulations for SB radius 0.82 mm, simulation 863
# Running simulations for SB radius 1.72 mm, simulation 864
# Running simulations for SB radius 1.65 mm, simulation 865
# Running simulations for SB radius 1.60 mm, simulation 866
# Running simulations for SB radius 1.20 mm, simulation 867
# Running simulations for SB radius 0.95 mm, simulation 868
# Running simulations for SB radius 0.97 mm, simulation 869
# Running simulations for SB radius 1.02 mm, simulation 870
# Running simulations for SB radius 1.23 mm, simulation 871
# Running simulations for SB radius 0.65 mm, simulation 872
# Running simulations for SB radius 1.70 mm, simulation 873
# Running simulations for SB radius 1.89 mm, simulation 874
# Running simulations for SB radius 1.00 mm, simulation 875
# Running simulations for SB radius 1.54 mm, simulation 876
# Running simulations for SB radius 1.00 mm, simulation 877
# Running simulations for SB radius 1.16 mm, simulation 878
# Running simulations for SB radius 0.21 mm, simulation 879
# Running simulations for SB radius 0.40 mm, simulation 880
# Running simulations for SB radius 1.17 mm, simulation 881
# Running simulations for SB radius 1.74 mm, simulation 882
# Running simulations for SB radius 0.93 mm, simulation 883
# Running simulations for SB radius 1.09 mm, simulation 884
# Running simulations for SB radius 0.95 mm, simulation 885
# Running simulations for SB radius 1.11 mm, simulation 886
# Running simulations for SB radius 0.69 mm, simulation 887
# Running simulations for SB radius 0.85 mm, simulation 888
# Running simulations for SB radius 0.45 mm, simulation 889
# Running simulations for SB radius 0.67 mm, simulation 890
# Running simulations for SB radius 1.93 mm, simulation 891
# Running simulations for SB radius 1.28 mm, simulation 892
# Running simulations for SB radius 1.45 mm, simulation 893
# Running simulations for SB radius 0.55 mm, simulation 894
# Running simulations for SB radius 2.25 mm, simulation 895
# Running simulations for SB radius 0.60 mm, simulation 896
# Running simulations for SB radius 0.65 mm, simulation 897
# Running simulations for SB radius 0.36 mm, simulation 898
# Running simulations for SB radius 0.75 mm, simulation 899
# Running simulations for SB radius 0.35 mm, simulation 900
# Running simulations for SB radius 0.84 mm, simulation 901
# Running simulations for SB radius 1.92 mm, simulation 902
# Running simulations for SB radius 1.34 mm, simulation 903
# Running simulations for SB radius 0.78 mm, simulation 904
# Running simulations for SB radius 1.79 mm, simulation 905
# Running simulations for SB radius 1.11 mm, simulation 906
# Running simulations for SB radius 1.17 mm, simulation 907
# Running simulations for SB radius 0.62 mm, simulation 908
# Running simulations for SB radius 1.72 mm, simulation 909
# Running simulations for SB radius 1.03 mm, simulation 910
# Running simulations for SB radius 1.21 mm, simulation 911
# Running simulations for SB radius 1.02 mm, simulation 912
# Running simulations for SB radius 0.95 mm, simulation 913
# Running simulations for SB radius 1.06 mm, simulation 914
# Running simulations for SB radius 1.10 mm, simulation 915
# Running simulations for SB radius 1.33 mm, simulation 916
# Running simulations for SB radius 1.24 mm, simulation 917
# Running simulations for SB radius 1.21 mm, simulation 918
# Running simulations for SB radius 1.10 mm, simulation 919
# Running simulations for SB radius 1.73 mm, simulation 920
# Running simulations for SB radius 2.16 mm, simulation 921
# Running simulations for SB radius 0.51 mm, simulation 922
# Running simulations for SB radius 1.48 mm, simulation 923
# Running simulations for SB radius 0.89 mm, simulation 924
# Running simulations for SB radius 1.06 mm, simulation 925
# Running simulations for SB radius 1.14 mm, simulation 926
# Running simulations for SB radius 0.92 mm, simulation 927
# Running simulations for SB radius 1.54 mm, simulation 928
# Running simulations for SB radius 0.86 mm, simulation 929
# Running simulations for SB radius 1.31 mm, simulation 930
# Running simulations for SB radius 0.84 mm, simulation 931
# Running simulations for SB radius 0.89 mm, simulation 932
# Running simulations for SB radius 0.96 mm, simulation 933
# Running simulations for SB radius 1.44 mm, simulation 934
# Running simulations for SB radius 2.02 mm, simulation 935
# Running simulations for SB radius 0.89 mm, simulation 936
# Running simulations for SB radius 1.52 mm, simulation 937
# Running simulations for SB radius 1.03 mm, simulation 938
# Running simulations for SB radius 1.31 mm, simulation 939
# Running simulations for SB radius 1.36 mm, simulation 940
# Running simulations for SB radius 1.57 mm, simulation 941
# Running simulations for SB radius 1.83 mm, simulation 942
# Running simulations for SB radius 1.94 mm, simulation 943
# Running simulations for SB radius 0.42 mm, simulation 944
# Running simulations for SB radius 1.79 mm, simulation 945
# Running simulations for SB radius 1.63 mm, simulation 946
# Running simulations for SB radius 0.14 mm, simulation 947
# Running simulations for SB radius 0.73 mm, simulation 948
# Running simulations for SB radius 1.09 mm, simulation 949
# Running simulations for SB radius 2.83 mm, simulation 950
# Running simulations for SB radius 1.14 mm, simulation 951
# Running simulations for SB radius 0.35 mm, simulation 952
# Running simulations for SB radius 1.17 mm, simulation 953
# Running simulations for SB radius 1.29 mm, simulation 954
# Running simulations for SB radius 1.27 mm, simulation 955
# Running simulations for SB radius 1.56 mm, simulation 956
# Running simulations for SB radius 0.73 mm, simulation 957
# Running simulations for SB radius 1.23 mm, simulation 958
# Running simulations for SB radius 1.36 mm, simulation 959
# Running simulations for SB radius 0.87 mm, simulation 960
# Running simulations for SB radius 1.24 mm, simulation 961
# Running simulations for SB radius 1.25 mm, simulation 962
# Running simulations for SB radius 1.43 mm, simulation 963
# Running simulations for SB radius 1.01 mm, simulation 964
# Running simulations for SB radius 1.23 mm, simulation 965
# Running simulations for SB radius 0.90 mm, simulation 966
# Running simulations for SB radius 1.00 mm, simulation 967
# Running simulations for SB radius 1.14 mm, simulation 968
# Running simulations for SB radius 1.10 mm, simulation 969
# Running simulations for SB radius 2.24 mm, simulation 970
# Running simulations for SB radius 1.57 mm, simulation 971
# Running simulations for SB radius 0.87 mm, simulation 972
# Running simulations for SB radius 1.31 mm, simulation 973
# Running simulations for SB radius 1.48 mm, simulation 974
# Running simulations for SB radius 0.52 mm, simulation 975
# Running simulations for SB radius 1.08 mm, simulation 976
# Running simulations for SB radius 1.30 mm, simulation 977
# Running simulations for SB radius 0.50 mm, simulation 978
# Running simulations for SB radius 1.12 mm, simulation 979
# Running simulations for SB radius 0.76 mm, simulation 980
# Running simulations for SB radius 0.98 mm, simulation 981
# Running simulations for SB radius 0.64 mm, simulation 982
# Running simulations for SB radius 1.18 mm, simulation 983
# Running simulations for SB radius 2.09 mm, simulation 984
# Running simulations for SB radius 1.08 mm, simulation 985
# Running simulations for SB radius 0.41 mm, simulation 986
# Running simulations for SB radius 1.26 mm, simulation 987
# Running simulations for SB radius 1.79 mm, simulation 988
# Running simulations for SB radius 1.11 mm, simulation 989
# Running simulations for SB radius 1.10 mm, simulation 990
# Running simulations for SB radius 1.01 mm, simulation 991
# Running simulations for SB radius 1.06 mm, simulation 992
# Running simulations for SB radius 0.80 mm, simulation 993
# Running simulations for SB radius 1.91 mm, simulation 994
# Running simulations for SB radius 0.71 mm, simulation 995
# Running simulations for SB radius 2.84 mm, simulation 996
# Running simulations for SB radius 1.19 mm, simulation 997
# Running simulations for SB radius 0.45 mm, simulation 998
# Running simulations for SB radius 1.11 mm, simulation 999

# %%
# Repeat R3 array to match TS and freqs
R3_sims = ml.repmat(R3_ensemble,1, nfreqs)
R3_simulations = R3_sims.reshape(-1)

#freqs_sims = ml.repmat(freqs,1, nfreqs)
#freqs_simulations = freqs_sims.reshape(-1)

# %% [markdown]
# ## Create dataframe for results

# %%
ve_simdata=pd.DataFrame({'freqs':freqs/1000,'TS_lima':TS_simulations, 'R3 (mm)': R3_simulations*1000})

# %% [markdown]
# # Plot results
# Colour is used to indicated the effect of shape (Limacina radius at the angle of incidence) on the frequency response.

# %%
plt.figure(figsize=(8,8))
sns.lineplot(data=ve_simdata, x='freqs',y='TS_lima',hue='R3 (mm)')
plt.ylabel('Target Strength (dB re 1 m^2)')
plt.xlabel('Frequency (kHz)')
plt.xlim([100, 600]);

# %%
plt.figure(figsize=(8,8))
sns.lineplot(data=ve_simdata, x='freqs',y='TS_lima',hue='R3 (mm)')
plt.ylabel('Target Strength (dB re 1 m^2)')
plt.xlabel('Frequency (kHz)')
plt.title('Limacina viscous-elastic model simulations')
plt.xlim([185, 383]);

# %% [markdown]
# # Put it all in a matrix

# %%
F_TS_MAT=np.concatenate((freqs.reshape(-1,1),TS_simulations.reshape(-1,1)),axis=1)
plt.plot(F_TS_MAT[:,0],F_TS_MAT[:,1], '.', markersize=0.1)

# %% [markdown]
# ## Write to file
# Write the results in a text file with a header of parameters and a row for each frequency and TS.
#
# Should I add R3?

# %%
# uncomment when ready.
vefunc.write_ve('./ve_results/ve_simulations_limacina.txt', M_order, params_lima, F_TS_MAT)

# %%
ve_simdata['sigbs'] = 10**(ve_simdata['TS_lima']/10)
mean_bs = ve_simdata.groupby(["freqs"]).agg({'sigbs':'mean'})

# %%
plt.figure(figsize=(6,5))
sns.lineplot(data=ve_simdata, x='freqs',y='TS_lima')
plt.ylabel('Target Strength (dB re 1 $m^2$)', axis_font)
plt.xlabel('Frequency (kHz)', axis_font)
plt.title('Limacina', title_font)
# Out:
# Text(0.5, 1.0, 'Limacina')

# %%
plt.figure(figsize=(6,5))
sns.lineplot(data=ve_simdata, x='freqs',y='TS_lima')
plt.ylabel('Target Strength (dB re 1 $m^2$)', axis_font)
plt.xlabel('Frequency (kHz)', axis_font)
plt.title('Limacina', title_font)
plt.xlim([282,383])
# Out:
# (282.0, 383.0)

# %%
# k = 2pi/lambda = 2pi*f/c
ve_simdata['ka'] = (R3_simulations*1e-3)*2*np.pi*freqs/1480

# %%
middle_ka = np.mean(R3_simulations*1e-3)*2*np.pi*333000/1480

# %%
plt.figure(figsize=(6,5))
sns.lineplot(data=ve_simdata, x='ka',y='TS_lima')
#plt.plot([middle_ka, middle_ka],[-140, -40])
plt.ylabel('Target Strength (dB re 1 $m^2$)', axis_font)
plt.xlabel('ka', axis_font)
plt.title('Limacina', title_font)
# Out:
# Text(0.5, 1.0, 'Limacina')

# %% [markdown]
# # CI boot

# %%
simulations=ve_simdata
n_boots=100
percentiles=(2.5, 97.5)
# First, calculate mean for each frequency of the whole sample
mean_bs = simulations.groupby(['freqs']).mean()['sigbs']


# Resample , calculate mean repeat n_boot times, then calculate the SPREAD of the MEANS.
sigbs = simulations.sigbs
freq = simulations.freqs
freqs = np.unique(freq)

# Create our empty array to fill the results
ci_boot = np.zeros([2, len(freqs)])

# Resample over each frequency
for i in range(len(freqs)):
    sigbs_selectfreq = sigbs[freq==freqs[i]]

    # Create our empty array to fill the results              
    bootstrap_means = np.zeros([n_boots])

    # Resample within the values of the selected frequency and calculate the mean
    for ii in range(n_boots):
    # Generate random indices for our data *with* replacement, then take the sample mean
        random_sample = resample(sigbs_selectfreq)
        bootstrap_means[ii] = random_sample.mean(axis=0)

    # Save the percentiles of the bootstraped means for the selected frequency
    ci_boot[:,i] = np.percentile(bootstrap_means, percentiles, axis=0)

# %%
plt.figure(figsize=(5,4))
plt.plot(freqs, mean_bs, 'r')
plt.fill_between(freqs, ci_boot[0,:], ci_boot[1,:], alpha=0.5, color='r')
plt.ylabel('Cross sectional backscatter ($m^{2}$)', axis_font)
plt.xlabel('Frequency (kHz)', axis_font)
plt.title('Limacina', title_font)
# Out:
# Text(0.5, 1.0, 'Limacina')
